# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
#import Librairies.ipynb as Plib

df = pd.read_csv('./data/sales_predictions.csv');

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
sb.relplot(x="date", y="item_price", data=df)

# %%
sb.relplot(x = "date", y = "item_price", data = df.sample(n = 50))

# %%
my_relplot = sb.relplot(x = "date", y = "item_price", data = df.sample(n = 50))
my_relplot.fig.set_figwidth(20)
my_relplot.fig.set_figheight(6)

# %%
df.date
# Out:
# 0          02.01.2013
# 1          03.01.2013
# 2          05.01.2013
# 3          06.01.2013
# 4          15.01.2013
#               ...
# 2935844    10.10.2015
# 2935845    09.10.2015
# 2935846    14.10.2015
# 2935847    22.10.2015
# 2935848    03.10.2015
# Name: date, Length: 2935849, dtype: object

# %%
df.date = pd.to_datetime(df.date)
df.date
# Out:
# 0         2013-02-01
# 1         2013-03-01
# 2         2013-05-01
# 3         2013-06-01
# 4         2013-01-15
#              ...
# 2935844   2015-10-10
# 2935845   2015-09-10
# 2935846   2015-10-14
# 2935847   2015-10-22
# 2935848   2015-03-10
# Name: date, Length: 2935849, dtype: datetime64[ns]

# %%
import datetime 
my_relplot = sb.relplot(x = "date", y = "item_price", data = df.sample(n = 50))
my_relplot.fig.set_figwidth(20)
my_relplot.fig.set_figheight(6)
